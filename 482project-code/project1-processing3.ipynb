# %%
import json
import os
import glob
import numpy as np
import pandas as pd

polarity_amazon={}
polarity_google={}
polarity_facebook={}
polarity_apple={}

with open("amazon_results.txt") as f:
    line=f.readline()
    while(line):
        split_line=line.strip().split(",")
        
        polarity_amazon[split_line[0]]=split_line[1:]
        line=f.readline()
with open("apple_results.txt") as f:
    line=f.readline()
    while(line):
        split_line=line.strip().split(",")
        polarity_apple[split_line[0]]=split_line[1:]
        line=f.readline()
with open("facebook_results.txt") as f:
    line=f.readline()
    while(line):
        split_line=line.strip().split(",")
        polarity_facebook[split_line[0]]=split_line[1:]
        line=f.readline()
with open("google_results.txt") as f:
    line=f.readline()
    while(line):
        split_line=line.strip().split(",")
        polarity_google[split_line[0]]=split_line[1:]
        line=f.readline()

price = pd.read_csv( 'AMZN.csv',header=0 )
dates=list(price['Date'])
opens=list(price['Open'])
highs=list(price['High'])
lows=list(price['Low'])
closes=list(price['Close'])
adjCloses=list(price['Adj Close'])
volumes=list(price['Volume'])
rows=[]
upsAndDown=list(price['ups and down'])
for i in range(len(dates)):
    date=dates[i]
    #check if date is in polarity
    if(date in polarity_amazon):
        new_list=[]
        new_list.append(date)
        new_list.append(opens[i])
        new_list.append(highs[i])
        new_list.append(lows[i])
        new_list.append(closes[i])
        new_list.append(adjCloses[i])
        new_list.append(volumes[i])
#         new_list.append(upsAndDown[i])
        new_list+=(polarity_amazon[date])
        rows.append(new_list)
    else:
        new_list=[]
        new_list.append(date)
        new_list.append(opens[i])
        new_list.append(highs[i])
        new_list.append(lows[i])
        new_list.append(closes[i])
        new_list.append(adjCloses[i])
        new_list.append(volumes[i])
#         new_list.append(upsAndDown[i])
        new_list+=[0.3333333333333333,0.3333333333333333,0.3333333333333333]
        rows.append(new_list)
df=pd.DataFrame(np.array(rows),columns=['Date','Open','High','Low','Close','Adj Close','Volume','pos','neg','neu'])
df.to_csv('amazon_result.csv', index = None, header=True)

price = pd.read_csv( 'AAPL.csv',header=0 )
dates=list(price['Date'])
opens=list(price['Open'])
highs=list(price['High'])
lows=list(price['Low'])
closes=list(price['Close'])
adjCloses=list(price['Adj Close'])
volumes=list(price['Volume'])
rows=[]
upsAndDown=list(price['ups and down'])
for i in range(len(dates)):
    date=dates[i]
    #check if date is in polarity
    if(date in polarity_apple):
        new_list=[]
        new_list.append(date)
        new_list.append(opens[i])
        new_list.append(highs[i])
        new_list.append(lows[i])
        new_list.append(closes[i])
        new_list.append(adjCloses[i])
        new_list.append(volumes[i])
#         new_list.append(upsAndDown[i])
        new_list+=(polarity_apple[date])
        rows.append(new_list)
    else:
        new_list=[]
        new_list.append(date)
        new_list.append(opens[i])
        new_list.append(highs[i])
        new_list.append(lows[i])
        new_list.append(closes[i])
        new_list.append(adjCloses[i])
        new_list.append(volumes[i])
#         new_list.append(upsAndDown[i])
        new_list+=[0.3333333333333333,0.3333333333333333,0.3333333333333333]
        rows.append(new_list)
df=pd.DataFrame(np.array(rows),columns=['Date','Open','High','Low','Close','Adj Close','Volume','pos','neg','neu'])
df.to_csv('apple_result.csv', index = None, header=True)

price = pd.read_csv( 'FB.csv',header=0 )
dates=list(price['Date'])
opens=list(price['Open'])
highs=list(price['High'])
lows=list(price['Low'])
closes=list(price['Close'])
adjCloses=list(price['Adj Close'])
volumes=list(price['Volume'])
rows=[]
upsAndDown=list(price['ups and down'])
for i in range(len(dates)):
    date=dates[i]
    #check if date is in polarity
    if(date in polarity_facebook):
        new_list=[]
        new_list.append(date)
        new_list.append(opens[i])
        new_list.append(highs[i])
        new_list.append(lows[i])
        new_list.append(closes[i])
        new_list.append(adjCloses[i])
        new_list.append(volumes[i])
#         new_list.append(upsAndDown[i])
        new_list+=(polarity_facebook[date])
        rows.append(new_list)
    else:
        new_list=[]
        new_list.append(date)
        new_list.append(opens[i])
        new_list.append(highs[i])
        new_list.append(lows[i])
        new_list.append(closes[i])
        new_list.append(adjCloses[i])
        new_list.append(volumes[i])
#         new_list.append(upsAndDown[i])
        new_list+=[0.3333333333333333,0.3333333333333333,0.3333333333333333]
        rows.append(new_list)
df=pd.DataFrame(np.array(rows),columns=['Date','Open','High','Low','Close','Adj Close','Volume','pos','neg','neu'])
df.to_csv('facebook_result.csv', index = None, header=True)

price = pd.read_csv( 'GOOG.csv',header=0 )
dates=list(price['Date'])
opens=list(price['Open'])
highs=list(price['High'])
lows=list(price['Low'])
closes=list(price['Close'])
adjCloses=list(price['Adj Close'])
volumes=list(price['Volume'])
rows=[]
upsAndDown=list(price['ups and down'])
for i in range(len(dates)):
    date=dates[i]
    #check if date is in polarity
    if(date in polarity_google):
        new_list=[]
        new_list.append(date)
        new_list.append(opens[i])
        new_list.append(highs[i])
        new_list.append(lows[i])
        new_list.append(closes[i])
        new_list.append(adjCloses[i])
        new_list.append(volumes[i])
#         new_list.append(upsAndDown[i])
        new_list+=(polarity_google[date])
        rows.append(new_list)
    else:
        new_list=[]
        new_list.append(date)
        new_list.append(opens[i])
        new_list.append(highs[i])
        new_list.append(lows[i])
        new_list.append(closes[i])
        new_list.append(adjCloses[i])
        new_list.append(volumes[i])
#         new_list.append(upsAndDown[i])
        new_list+=[0.3333333333333333,0.3333333333333333,0.3333333333333333]
        rows.append(new_list)
df=pd.DataFrame(np.array(rows),columns=['Date','Open','High','Low','Close','Adj Close','Volume','pos','neg','neu'])
df.to_csv('google_result.csv', index = None, header=True)
